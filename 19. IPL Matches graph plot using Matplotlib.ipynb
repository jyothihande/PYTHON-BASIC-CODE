# %% [raw]
# **PLOT FOLLOWING GRAPHS USING Matplotlib:
#
# matches per team - bar plot ***
# number of grounds -  list   ***
# number of matches per ground - bar plot  ****
# number of matches per year - bar plot    ****
# number of wins per team - bar plot
# venue vs toss decision - hist
#  XXX number player of match per player -  bar plot
# number of matches per empire - bar plot
# batting/bowling selected per team - hist   ****
# tosses won per team - bar plot ***
# team vs toss decision - hist
#
#
# autopct="%0.1f%%" for percentage display in pie

# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading matches dataset
ipl=pd.read_csv("E:\DATA SCIENCE\DEEP Learning\matches.csv")

# %%
# first five records of matches
ipl.head()
# Out:
#    id  season        city        date                  team1  \
# 0  60    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1  61    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2  62    2008       Delhi  19-04-2008       Rajasthan Royals
# 3  63    2008      Mumbai  20-04-2008         Mumbai Indians
# 4  64    2008     Kolkata  20-04-2008        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
# number of rows and columns in the dataset 
ipl.shape
# Out:
# (756, 18)

# %%
ipl.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %% [markdown]
# # 1.PLOT matches per team - bar plot

# %%
team_1_2=pd.concat([a['team1'],a['team2']])
team_1_2
# Out:
# 0      Kolkata Knight Riders
# 1        Chennai Super Kings
# 2           Rajasthan Royals
# 3             Mumbai Indians
# 4            Deccan Chargers
#                ...
# 751           Mumbai Indians
# 752           Mumbai Indians
# 753           Delhi Capitals
# 754      Chennai Super Kings
# 755      Chennai Super Kings
# Length: 1512, dtype: object

# %%
team_unique=team_1_2.unique()
team_unique
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Deccan Chargers', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
team_count=team_1_2.value_counts()
team_count
# Out:
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# Delhi Daredevils               161
# Rajasthan Royals               147
# Sunrisers Hyderabad            108
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Delhi Capitals                  16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
plt.barh(team_unique,team_count,height=0.5)
plt.xlabel("Number of matches",fontsize=15,c='r')
plt.ylabel("Team Names ",fontsize=15,c='r')
plt.title("Matches per team",fontsize=15)
plt.grid(axis='x',c='r')
plt.show()

# %% [markdown]
# # 2.PLOT Number of matches per ground - "bar plot"

# %%
venue_count =a['venue'].value_counts()
venue_count = venue_count.values

# %%
venue_name= a['venue'].unique()
venue_name
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association Stadium, Mohali', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'MA Chidambaram Stadium, Chepauk', 'Dr DY Patil Sports Academy',
#        'Newlands', "St George's Park", 'Kingsmead', 'SuperSport Park',
#        'Buffalo Park', 'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Holkar Cricket Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
# ...

# %%
df=pd.DataFrame(venue_name,columns=['venue name'])
df1=pd.DataFrame(venue_count,columns=['number of matches'])

# %%
df0=pd.concat([df,df1],axis=1)
df0
# Out:
#                                            venue name  number of matches
# 0                               M Chinnaswamy Stadium                 77
# 1          Punjab Cricket Association Stadium, Mohali                 73
# 2                                    Feroz Shah Kotla                 73
# 3                                    Wankhede Stadium                 67
# 4                                        Eden Gardens                 56
# 5                              Sawai Mansingh Stadium                 49
# 6           Rajiv Gandhi International Stadium, Uppal                 47
# 7                     MA Chidambaram Stadium, Chepauk                 35
# 8                          Dr DY Patil Sports Academy                 21
# 9                                            Newlands                 17
# 10                                   St George's Park                 17
# 11                                          Kingsmead                 15
# ...

# %%
plt.barh(df0['venue name'],df0['number of matches'],height=0.5)
plt.xlabel("Number of matches",fontsize=15,c='r')
plt.ylabel("Venue ",fontsize=15,c='r')
plt.title("Matches per team",fontsize=15)
plt.grid(axis='x',c='g')
plt.show()

# %% [markdown]
# # 3.PLOT number of matches per year - bar plot

# %%
year=a['season'].unique()
year
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019], dtype=int64)

# %% [raw]
# plt.barh(year,team_count,height=0.8)
# plt.xlabel("Ground Name",fontsize=15,c='r')
# plt.ylabel("Number of matches ",fontsize=15,c='r')
# plt.title("Matches per team",fontsize=15)
# plt.grid(axis='x',c='r')
# plt.show()

# %%
x
# Out:
#     year
# 0   2008
# 1   2009
# 2   2010
# 3   2011
# 4   2012
# 5   2013
# 6   2014
# 7   2015
# 8   2016
# 9   2017
# 10  2018
# 11  2019

# %% [markdown]
# #   4. Maximum Man of the match award winner

# %%
# top five man of the match
ipl['player_of_match'].value_counts()[0:5]  # y axis
# Out:
# CH Gayle          21
# AB de Villiers    20
# DA Warner         17
# RG Sharma         17
# MS Dhoni          17
# Name: player_of_match, dtype: int64

# %%
list(ipl['player_of_match'].value_counts()[0:5].keys())  # X axis
# Out:
# ['CH Gayle', 'AB de Villiers', 'DA Warner', 'RG Sharma', 'MS Dhoni']

# %%
plt.figure(figsize=(8,5))
plt.bar(list(ipl['player_of_match'].value_counts()[0:5].keys()),list(ipl['player_of_match'].value_counts()[0:5]),color="y")
plt.xlabel("Name of players",fontsize=15,c='r')
plt.ylabel("Number of matches ",fontsize=15,c='r')
plt.title("Man of the match",fontsize=15)
plt.show()

# %%
ipl['result'].unique()
# Out:
# array(['normal', 'tie', 'no result'], dtype=object)

# %%
# geting frequencies of result column
ipl['result'].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %% [markdown]
# # 5.  Tosses won per team - bar plot

# %%
# finding out number of matches win w r t each team
ipl['toss_winner'].value_counts()
#
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Rajasthan Royals               80
# Delhi Daredevils               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
plt.barh(list(ipl['toss_winner'].value_counts().keys()),list(ipl['toss_winner'].value_counts()),height=0.5)
plt.xlabel("Number of tosses",fontsize=15,c='r')
plt.ylabel("Team Names ",fontsize=15,c='r')
plt.title("Matches per team",fontsize=15)
plt.grid(axis='x',c='r')
plt.show()

# %% [markdown]
# # 6.batting/bowling selected per team - hist

# %%
#Extracting the records where a team won batting first

# %%
batting_first=ipl[ipl['win_by_runs']!=0]

# %%
batting_first.head()
# Out:
#     id  season        city        date                  team1  \
# 0   60    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1   61    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 7   67    2008     Chennai  23-04-2008    Chennai Super Kings
# 9   69    2008  Chandigarh  25-04-2008        Kings XI Punjab
# 14  74    2008   Bangalore  28-04-2008    Chennai Super Kings
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1               Kings XI Punjab          Chennai Super Kings           bat
# 7                Mumbai Indians               Mumbai Indians         field
# 9                Mumbai Indians               Mumbai Indians         field
# 14  Royal Challengers Bangalore          Chennai Super Kings           bat
#
#     result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# ...

# %%
plt.figure(figsize=(7,7))
plt.hist(batting_first['win_by_runs'],color="y")
plt.xlabel("number of runs by which team won",fontsize=15,c='r')
plt.ylabel("Number of times team bats first ",fontsize=15,c='r')
plt.title("Runs by a team won batting first",fontsize=15)
plt.show()

# %% [markdown]
# # 7. find number of wins w r t each team after batting first

# %%
batting_first['winner'].value_counts()
# mumbai indian chose 57 times to bat first
# Out:
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            30
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Delhi Capitals                  3
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.barh(list(batting_first['winner'].value_counts()[0:5].keys()),list(batting_first['winner'].value_counts()[0:5]),color=['y','b','r','pink','g'])
plt.xlabel("Number of matches",fontsize=15,c='r')
plt.ylabel("Names of matches ",fontsize=15,c='r')
plt.title("Winning teams and matches",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.pie(list(batting_first['winner'].value_counts()),labels=list(batting_first['winner'].value_counts().keys()),autopct="%0.1f%%")
plt.show()

# %% [markdown]
# autopct="%0.1f%%" for percentage display in pie

# %%
#Number if matches played each season
ipl['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2015    59
# 2017    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
# number of matches in each cities
ipl['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Mohali             10
# Rajkot             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Abu Dhabi           7
# Ranchi              7
# Cape Town           7
# Cuttack             7
# Port Elizabeth      7
# Raipur              6
# Sharjah             6
# Kochi               5
# Kanpur              4
# East London         3
# Nagpur              3
# Kimberley           3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
np.sum(ipl['toss_winner']==ipl['winner'])
# Out:
# 393

# %% [markdown]
# # 8. Number of grounds -  list

# %%
ipl['venue'].value_counts()
# Out:
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Brabourne Stadium                                       11
# ...

# %%
list(ipl['venue'])
# Out:
# ['M Chinnaswamy Stadium',
#  'Punjab Cricket Association Stadium, Mohali',
#  'Feroz Shah Kotla',
#  'Wankhede Stadium',
#  'Eden Gardens',
#  'Sawai Mansingh Stadium',
#  'Rajiv Gandhi International Stadium, Uppal',
#  'MA Chidambaram Stadium, Chepauk',
#  'Rajiv Gandhi International Stadium, Uppal',
#  'Punjab Cricket Association Stadium, Mohali',
#  'M Chinnaswamy Stadium',
#  'MA Chidambaram Stadium, Chepauk',
#  'Dr DY Patil Sports Academy',
#  'Punjab Cricket Association Stadium, Mohali',
#  'M Chinnaswamy Stadium',
#  'Eden Gardens',
#  'Feroz Shah Kotla',
#  'Rajiv Gandhi International Stadium, Uppal',
#  'Sawai Mansingh Stadium',
#  'MA Chidambaram Stadium, Chepauk',
#  'Rajiv Gandhi International Stadium, Uppal',
#  'Punjab Cricket Association Stadium, Mohali',
#  'Dr DY Patil Sports Academy',
#  'Sawai Mansingh Stadium',
#  'M Chinnaswamy Stadium',
#  'MA Chidambaram Stadium, Chepauk',
#  'Dr DY Patil Sports Academy',
#  'Feroz Shah Kotla',
#  'Eden Gardens',
# ...

# %% [markdown]
# #  9. Number of matches per empire - bar plot

# %%
ipl['umpire1'].value_counts()
# Out:
# HDPK Dharmasena    73
# Asad Rauf          51
# S Ravi             49
# AK Chaudhary       43
# Aleem Dar          38
#                    ..
# Ulhas Gandhe        1
# SJA Taufel          1
# SL Shastri          1
# A Nanda Kishore     1
# Sundaram Ravi       1
# Name: umpire1, Length: 61, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.barh(list(ipl['umpire1'].value_counts()[0:10].keys()),list(ipl['umpire1'].value_counts()[0:10]),color=['y','b','r','pink','g','orange','purple','black','grey','maroon'])
plt.xlabel("Number of matches",fontsize=15,c='r')
plt.ylabel("Names of umpires ",fontsize=15,c='r')
plt.title("Per Umpires matches",fontsize=15)
plt.show()

# %%
ipl['umpire2'].value_counts()
# Out:
# S Ravi              57
# C Shamshuddin       57
# SJA Taufel          54
# RJ Tucker           38
# CK Nandan           36
#                     ..
# Kumar Dharmasena     1
# SJ Davis             1
# JD Cloete            1
# Subroto Das          1
# Ian Gould            1
# Name: umpire2, Length: 65, dtype: int64

# %%
ipl['umpire3'].value_counts()
# Out:
# Nitin Menon                10
# O Nandan                   10
# C Shamshuddin              10
# Anil Chaudhary              9
# S Ravi                      8
# Vineet Kulkarni             8
# Bruce Oxenford              7
# Yeshwant Barde              7
# Anil Dandekar               7
# Chris Gaffaney              6
# Rod Tucker                  5
# Marais Erasmus              5
# Nigel Llong                 4
# A Nanda Kishore             3
# Nanda Kishore               3
# Ian Gould                   3
# A.D Deshmukh                2
# K Ananthapadmanabhan        2
# Virender Kumar Sharma       2
# Kumar Dharmasena            2
# Ulhas Gandhe                2
# KN Anantapadmanabhan        1
# Sundaram Ravi               1
# KN Ananthapadmanabhan       1
# Chettithody Shamshuddin     1
# Name: umpire3, dtype: int64
